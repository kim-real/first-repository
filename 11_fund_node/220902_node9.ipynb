# %%
#파이썬은 Pandas, Matplotlib, Seaborn 등 여러 가지 시각화 라이브러리를 제공
#matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline                   

# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']     #list
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()               #?그림(figure) 객체 .. 객체 생성 , 
                                 # fig = plt.figure(figsize=(5,2)), 도화지 생성:figure()),  그래프크기figsize=(5,2)
ax1 = fig.add_subplot(1,1,1)      #축 ,  nrows, ncols, index
                                  # nrows rows and ncols columns. index starts at 1 in the upper left corner and increases to the right.

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")

# 보여주기
plt.savefig('./barplot.png')  # 그래프를 이미지로 출력
plt.show()                    # 그래프를 화면으로 출력

# %%
#객제
fig = plt.figure()

# %%
#도와지와 그레츠
fig = plt.figure(figsize=(5,2))
ax1 = fig.add_subplot(1,1,1)

# %%
# 축 비교 ?
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  # 2행 2열 1번째
ax2 = fig.add_subplot(2,2,2)  # 2행 2열 2번째
ax3 = fig.add_subplot(2,2,4)  # 2행 2열 4번째

# %%
#bar() 메서드를 이용해 막대그래프를 그립니다. 그리고 인자에 위에서 정의한 데이터들을 x, y
# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject,points)
# Out:
# <BarContainer object of 5 artists>

# %%
#그래프2
from datetime import datetime
import pandas as pd
import os

# 그래프 데이터 
csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/AMZN.csv"
data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
price = data['Close']                            # Pandas의 Series

# 축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
price.plot(ax=ax, style='black')              # Pandas의 plot을 
plt.ylim([1600,2200])                          #x 눈금
plt.xlim(['2019-05-01','2020-03-01'])

# 주석달기
important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10),  # 주석을 달 좌표(x,y) annotate???
                xytext=(d,price.asof(d)+100),     # 주석 텍스트가 위차할 좌표(x,y)
                arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %%
#9-5. 간단한 그래프 그리기 (3) plot 사용법 상세
# plt.plot() 명령으로 그래프를 그리면 matplotlib은 가장 최근의 figure 객체와 그 서브플롯
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 100) #0에서 10까지 균등한 간격으로  100개의 숫자를 만들라는 뜻입니다.
plt.plot(x, np.sin(x),'o')               #blue ,양 : 동그라미
plt.plot(x, np.cos(x),'--', color='black') 
plt.show()

# %%
#그래프2 : 2개의 그레프 subplot 
x = np.linspace(0, 10, 100) 

plt.subplot(2,1,1)
plt.plot(x, np.sin(x),'orange','o')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange') 
plt.show()

# %%
#라인스타일
x = np.linspace(0, 10, 100) 

plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted')
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
'''
pandas.plot 메서드 인자
label: 그래프의 범례 이름.
ax: 그래프를 그릴 matplotlib의 서브플롯 객체.
style: matplotlib에 전달할 'ko--'같은 스타일의 문자열
alpha: 투명도 (0 ~1)
kind: 그래프의 종류: line, bar, barh, kde
logy: Y축에 대한 로그 스케일
use_index: 객체의 색인을 눈금 이름으로 사용할지의 여부
rot: 눈금 이름을 로테이션(0 ~ 360)
xticks, yticks: x축, y축으로 사용할 값
xlim, ylim: x축, y축 한계
grid: 축의 그리드 표시할지 여부

pandas의 data가 DataFrame 일 때 plot 메서드 인자
subplots: 각 DataFrame의 칼럼을 독립된 서브플롯에 그린다.
sharex: subplots=True 면 같은 X 축을 공유하고 눈금과 한계를 연결한다.
sharey: subplots=True 면 같은 Y 축을 공유한다.
figsize: 그래프의 크기, 튜플로 지정
title: 그래프의 제목을 문자열로 지정
sort_columns: 칼럼을 알파벳 순서로 그린다.
'''

# %%
#막대그래프
import pandas as pd
fig, axes = plt.subplots(2, 1)    #그레프 2개 
data = pd.Series(np.random.rand(5), index=list('abcde'))   #data 랜덤 , 눈금
data.plot(kind='bar', ax=axes[0], color='blue', alpha=1)
data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)  #alpha=0.3 칙칙함
# Out:
# <AxesSubplot:>

# %%
#선그레프   6열 4행 랜텀 발생
df = pd.DataFrame(np.random.rand(6,4), columns=pd.Index(['A','B','C','D']))
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
# 그리는 법
'''fig = plt.figure(): figure 객체를 선언해 '도화지를 펼쳐' 줍니다.
ax1 = fig.add_subplot(1,1,1) : 축을 그립니다.
ax1.bar(x, y) 축안에 어떤 그래프를 그릴지 메서드를 선택한 다음, 인자로 데이터를 넣어줍니다.
그래프 타이틀 축의 레이블 등을 plt의 여러 메서드 grid, xlabel, ylabel 을 이용해서 추가해 주고
plt.savefig 메서드를 이용해 저장해 줍니다.
'''

# %%
#Seaborn의 load_dataset() 예제 data 다운
#연습data : https://github.com/mwaskom/seaborn-data
#default directory: ~/seaborn-data/ (~(물결표시)는 home directory
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")    # tipsdata 가져옴 .. 팁스타운

# %%
#데이터 구성 살펴보기
df = pd.DataFrame(tips)     #tip > data frame 전환
df.head()                   # head 5줄 보기
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#행열 구성  244행 7열
df.shape
# Out:
# (244, 7)

# %%
# 통계 자료 
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# data frame이고 , 행열 모양 , col의 정보 ; name, data type,, 객제타입 , 메모리, 결측치 표현
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
#sex, smoker, day, time이 범주(category)형 데이터고 tips, total_bill, size는 수치형
print(df['sex'].value_counts())
print("===========================")

print(df['time'].value_counts())
print("===========================")

print(df['smoker'].value_counts())
print("===========================")

print(df['day'].value_counts())
print("===========================")

print(df['size'].value_counts())
print("===========================")
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64
# ...
# Dinner    176
# Lunch      68
# Name: time, dtype: int64
# ...
# No     151
# Yes     93
# Name: smoker, dtype: int64
# ...
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64
# ...
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64
# ...

# %%
#9-8. 그래프 4대 천왕 (2) 범주형 데이터
#1) 막대그래프(bar graph) , Pandas와 Matplotlib를 활용한 방법
#matplotlib에 데이터를 추가 pandas 데이터를 이용 못함. 데이터를 x에 series 또는 list, y에 list 형태로 
# tip 컬럼을 성별에 대한 평균 , pandas의 groupby 메서드
# df['tip'] 컬럼을 groupby() , groupby()의 인자는 sex , 성별 그룹 정보(총합, 평균, 데이터 량 등)가 grouped 객체에 저장
grouped = df['tip'].groupby(df['sex'])
grouped.mean() # 성별에 따른 팁의 평균
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
grouped.size() # 성별에 따른 데이터 량(팁 횟수)
# Out:
# sex
# Male      157
# Female     87
# Name: tip, dtype: int64

# %%
import numpy as np   
sex = dict(grouped.mean()) #평균 데이터를 딕셔너리 형태로 바꿔줍니다.
#sex
x = list(sex.keys())  
x
# Out:
# ['Male', 'Female']

# %%
import numpy as np   
sex = dict(grouped.mean()) #평균 데이터를 딕셔너리 형태로 바꿔줍니다.
#sex

y = list(sex.values())
y
# Out:
# [3.0896178343949043, 2.833448275862069]

# %%
import matplotlib.pyplot as plt

plt.bar(x = x, height = y)
plt.ylabel('tip[$]')
plt.title('Tip by Sex')
# Out:
# Text(0.5, 1.0, 'Tip by Sex')

# %%
#1-2) Seaborn과 Matplotlib을 활용한 간단한 방법
#sns.barplot의 인자로 df를 넣고 원하는 컬럼
sns.barplot(data=df, x='sex', y='tip')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
plt.figure(figsize=(10,6)) # 도화지 사이즈를 정합니다.
sns.barplot(data=df, x='sex', y='tip')
plt.ylim(0, 4) # y값의 범위를 정합니다.
plt.title('Tip by sex') # 그래프 제목을 정합니다.
# Out:
# Text(0.5, 1.0, 'Tip by sex')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='day', y='tip')
plt.ylim(0, 4)
plt.title('Tip by day')
# Out:
# Text(0.5, 1.0, 'Tip by day')

# %%
fig = plt.figure(figsize=(10,7))

ax1 = fig.add_subplot(2,2,1)
sns.barplot(data=df, x='day', y='tip',palette="ch:.25")

ax2 = fig.add_subplot(2,2,2)
sns.barplot(data=df, x='sex', y='tip')

ax3 = fig.add_subplot(2,2,4)
sns.violinplot(data=df, x='sex', y='tip')

ax4 = fig.add_subplot(2,2,3)
sns.violinplot(data=df, x='day', y='tip',palette="ch:.25")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.catplot(x="day", y="tip", jitter=False, data=tips)

# %%
#9-9. 그래프 4대 천왕 (3) 수치형 데이터
#수치형 데이터를 나타내는 데 가장 좋은 그래프는 산점도 혹은 선 그래프
#2) 산점도(scatter plot) hue인자에 'day'를 주어 요일(day)에 따른 tip과 total_bill의 관계를 시각화
sns.scatterplot(data=df , x='total_bill', y='tip', palette="ch:r=-.2,d=.3_r")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df , x='total_bill', y='tip', hue='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#3) 선 그래프(line graph)
#np.random.randn 함수는 표준 정규분포에서 난수를 생성하는 함수입니다. 
#cumsum()은 누적합을 구하는 함수입니다.
plt.plot(np.random.randn(50).cumsum())

# %%
#Seaborn을 활용하면 다음과 같이 그릴 수 있습니다.
import pandas as pd
import seaborn as sns
import numpy as np
sns.lineplot(x=x, y=np.sin(x))
#sns.lineplot(x=x, y=np.cos(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/363239690.py in <module>
#       3 import seaborn as sns
#       4 import numpy as np
# ----> 5 sns.lineplot(x=x, y=np.sin(x))
#       6 #sns.lineplot(x=x, y=np.cos(x))
#
# TypeError: ufunc 'sin' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#4) 히스토그램
#그래프 데이터 
mu1, mu2, sigma = 100, 130, 15
x1 = mu1 + sigma*np.random.randn(10000)
x2 = mu2 + sigma*np.random.randn(10000)

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
patches = ax1.hist(x1, bins=50, density=False) #bins는 x값을 총 50개 구간으로 나눈다는 뜻입니다.
patches = ax1.hist(x2, bins=50, density=False, alpha=0.5)
ax1.xaxis.set_ticks_position('bottom') # x축의 눈금을 아래 표시 
ax1.yaxis.set_ticks_position('left') #y축의 눈금을 왼쪽에 표시

# 라벨, 타이틀 달기
plt.xlabel('Bins')
plt.ylabel('Number of Values in Bin')
ax1.set_title('Two Frequency Distributions')

# 보여주기
plt.show()

# %%
# tips 데이터의 total_bill과 tips에 대해 히스토그램
sns.histplot(df['total_bill'], label = "total_bill")
sns.histplot(df['tip'], label = "tip").legend()# legend()를 이용하여 label을 표시해 줍니다.

# %%
#결제 금액 대비 팁의 비율을 나타내는 히스토그램
df['tip_pct'] = df['tip'] / df['total_bill']
df['tip_pct'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#kind='kde'로 확률 밀도 그래프
df['tip_pct'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#9-10. 시계열 데이터 시각화하기
#1. 데이터 가져오기  , . 연도의 각 달별로 탑승객 수
import os

csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/flights.csv"
data = pd.read_csv(csv_path)
flights = pd.DataFrame(data)
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
#그래프  년도 별 승객
sns.barplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.pointplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
#달별로 나누어 보기 위해 hue 인자에 'month'
sns.lineplot(data=flights, x='year', y='passengers', hue='month', palette='ch:.50')
plt.legend(bbox_to_anchor=(1.03, 1), loc=2) #legend 그래프 밖에 추가하기

# %%
sns.histplot(flights['passengers'])
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='Count'>

# %%
#9-11. Heatmap , 방대한 양의 데이터와 현상을 수치에 따른 색상,  모두 2차원으로 시각화
#pandas의 dataframe의 pivot() 메서드
#flights(DataFrame)을 탑승객 수를 year과 month로 pivot
pivot = flights.pivot(index='year', columns='month', values='passengers')
pivot
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
# 1954     227     293       229       188      204   302   264    235  234
# 1955     269     347       278       233      242   364   315    267  270
# 1956     313     405       306       277      284   413   374    317  318
# 1957     348     467       336       301      315   465   422    356  355
# 1958     348     505       337       318      340   491   435    362  363
# 1959     396     559       405       342      360   548   472    406  420
# 1960     461     606       432       391      417   622   535    419  472
#
# ...

# %%
sns.heatmap(pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(pivot, linewidths=.2, annot=True, fmt="d")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(pivot, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
